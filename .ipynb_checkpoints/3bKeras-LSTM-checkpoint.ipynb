# %%
# %matplotlib inline
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error as mse
import matplotlib.lines as lines
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

# %%
X = pd.read_csv("./data/processed/gw_stage.CSV",
                    parse_dates=['Datetime'],
                    index_col=['Datetime'])
print('Initial Input Size: ',X.shape)
y = pd.read_csv("./data/processed/spring.CSV",
                    parse_dates=['datetime'],
                    index_col=['datetime'])
key_value = np.loadtxt("./data/processed/NameKey.CSV", dtype= "str", delimiter=",", skiprows=1)
stationNames = { k:v for k,v in key_value }

tooClose=['8','9','10','12','14','25', '44', '61', '74']
for i in tooClose:
    print(stationNames[i])

#Drop values exctremely close to the Spring head
X.drop(X.columns[[8,9,10,12, 14, 25,44,61,74]], axis=1, inplace=True)
print("Excluded Input Shape: ", X.shape)
X.rename(columns = stationNames, inplace = True)
train_names=X.columns
# Out:
# Initial Input Size:  (1101, 76)
# NWFWMD-NITRATE
# NWFWMD-NITRATE
# NWFWMD-NITRATE
# NWFWMD-NITRATE
# WAKULLA CONDUIT WELL@WEST OF HWY 61
# NWFWMD GW-12F (RIVERSPRINGS MS)/S820
# St. Marks River @ San Marcos de Apalachee S.P.
# WAKULLA RIVER AT BOAT TRAM
# INDIAN SPRING RUN AT SR61
# Excluded Input Shape:  (1101, 67)

# %%
#Scale Value
mm=MinMaxScaler()
ss=StandardScaler()
X_ss=ss.fit_transform(X)
y_mm=mm.fit_transform(y)

#Splitting to a 70 Train:30 Test
X_train=X_ss[:770,:]
X_test=X_ss[770:,:]
y_train=y_mm[:770,:]
y_test=y_mm[770:,:]

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)

X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (770, 67)
# (770, 1)
# (331, 67)
# (331, 1)
# (770, 1, 67) (770, 1) (331, 1, 67) (331, 1)

# %%
# design network
model = Sequential()
model.add(LSTM(67, input_shape=(X_train.shape[1], X_train.shape[2]), dropout = 0.3))
model.add(Dense(67))
model.add(Dense(1))
model.compile(loss='mse', optimizer='adam')
# fit network
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test), verbose=2, shuffle=False)
# plot history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 25/25 - 6s - loss: 0.1004 - val_loss: 0.0742 - 6s/epoch - 252ms/step
# Epoch 2/100
# 25/25 - 0s - loss: 0.0804 - val_loss: 0.0686 - 192ms/epoch - 8ms/step
# Epoch 3/100
# 25/25 - 0s - loss: 0.0680 - val_loss: 0.0395 - 204ms/epoch - 8ms/step
# Epoch 4/100
# 25/25 - 0s - loss: 0.0193 - val_loss: 0.0617 - 201ms/epoch - 8ms/step
# Epoch 5/100
# 25/25 - 0s - loss: 0.0172 - val_loss: 0.0203 - 208ms/epoch - 8ms/step
# Epoch 6/100
# 25/25 - 0s - loss: 0.0133 - val_loss: 0.0518 - 208ms/epoch - 8ms/step
# Epoch 7/100
# 25/25 - 0s - loss: 0.0214 - val_loss: 0.0128 - 200ms/epoch - 8ms/step
# Epoch 8/100
# 25/25 - 0s - loss: 0.0149 - val_loss: 0.0245 - 216ms/epoch - 9ms/step
# Epoch 9/100
# 25/25 - 0s - loss: 0.0143 - val_loss: 0.0109 - 320ms/epoch - 13ms/step
# Epoch 10/100
# 25/25 - 0s - loss: 0.0088 - val_loss: 0.0153 - 216ms/epoch - 9ms/step
# Epoch 11/100
# 25/25 - 0s - loss: 0.0095 - val_loss: 0.0099 - 200ms/epoch - 8ms/step
# Epoch 12/100
# 25/25 - 0s - loss: 0.0075 - val_loss: 0.0100 - 208ms/epoch - 8ms/step
# Epoch 13/100
# 25/25 - 0s - loss: 0.0064 - val_loss: 0.0073 - 192ms/epoch - 8ms/step
# Epoch 14/100
# 25/25 - 0s - loss: 0.0063 - val_loss: 0.0111 - 216ms/epoch - 9ms/step
# Epoch 15/100
# 25/25 - 0s - loss: 0.0061 - val_loss: 0.0063 - 200ms/epoch - 8ms/step
# Epoch 16/100
# 25/25 - 0s - loss: 0.0063 - val_loss: 0.0105 - 200ms/epoch - 8ms/step
# Epoch 17/100
# 25/25 - 0s - loss: 0.0060 - val_loss: 0.0068 - 296ms/epoch - 12ms/step
# Epoch 18/100
# 25/25 - 0s - loss: 0.0059 - val_loss: 0.0063 - 312ms/epoch - 12ms/step
# Epoch 19/100
# 25/25 - 0s - loss: 0.0058 - val_loss: 0.0080 - 224ms/epoch - 9ms/step
# Epoch 20/100
# 25/25 - 0s - loss: 0.0057 - val_loss: 0.0052 - 216ms/epoch - 9ms/step
# Epoch 21/100
# 25/25 - 0s - loss: 0.0068 - val_loss: 0.0109 - 224ms/epoch - 9ms/step
# Epoch 22/100
# 25/25 - 0s - loss: 0.0068 - val_loss: 0.0045 - 232ms/epoch - 9ms/step
# Epoch 23/100
# 25/25 - 0s - loss: 0.0083 - val_loss: 0.0159 - 216ms/epoch - 9ms/step
# Epoch 24/100
# 25/25 - 0s - loss: 0.0073 - val_loss: 0.0053 - 200ms/epoch - 8ms/step
# Epoch 25/100
# 25/25 - 0s - loss: 0.0079 - val_loss: 0.0106 - 192ms/epoch - 8ms/step
# Epoch 26/100
# 25/25 - 0s - loss: 0.0081 - val_loss: 0.0065 - 192ms/epoch - 8ms/step
# Epoch 27/100
# 25/25 - 0s - loss: 0.0074 - val_loss: 0.0072 - 208ms/epoch - 8ms/step
# Epoch 28/100
# 25/25 - 0s - loss: 0.0089 - val_loss: 0.0108 - 208ms/epoch - 8ms/step
# Epoch 29/100
# 25/25 - 0s - loss: 0.0105 - val_loss: 0.0058 - 184ms/epoch - 7ms/step
# Epoch 30/100
# 25/25 - 0s - loss: 0.0148 - val_loss: 0.0085 - 200ms/epoch - 8ms/step
# Epoch 31/100
# 25/25 - 0s - loss: 0.0104 - val_loss: 0.0059 - 232ms/epoch - 9ms/step
# Epoch 32/100
# 25/25 - 0s - loss: 0.0090 - val_loss: 0.0081 - 272ms/epoch - 11ms/step
# Epoch 33/100
# 25/25 - 0s - loss: 0.0071 - val_loss: 0.0075 - 232ms/epoch - 9ms/step
# Epoch 34/100
# 25/25 - 0s - loss: 0.0079 - val_loss: 0.0056 - 232ms/epoch - 9ms/step
# Epoch 35/100
# 25/25 - 0s - loss: 0.0076 - val_loss: 0.0058 - 224ms/epoch - 9ms/step
# Epoch 36/100
# 25/25 - 0s - loss: 0.0052 - val_loss: 0.0053 - 332ms/epoch - 13ms/step
# Epoch 37/100
# 25/25 - 0s - loss: 0.0052 - val_loss: 0.0046 - 312ms/epoch - 12ms/step
# Epoch 38/100
# 25/25 - 0s - loss: 0.0058 - val_loss: 0.0063 - 312ms/epoch - 12ms/step
# Epoch 39/100
# 25/25 - 0s - loss: 0.0060 - val_loss: 0.0044 - 368ms/epoch - 15ms/step
# Epoch 40/100
# 25/25 - 0s - loss: 0.0091 - val_loss: 0.0084 - 208ms/epoch - 8ms/step
# Epoch 41/100
# 25/25 - 0s - loss: 0.0085 - val_loss: 0.0054 - 224ms/epoch - 9ms/step
# Epoch 42/100
# 25/25 - 0s - loss: 0.0086 - val_loss: 0.0095 - 224ms/epoch - 9ms/step
# Epoch 43/100
# 25/25 - 0s - loss: 0.0062 - val_loss: 0.0094 - 320ms/epoch - 13ms/step
# Epoch 44/100
# 25/25 - 0s - loss: 0.0072 - val_loss: 0.0058 - 288ms/epoch - 12ms/step
# Epoch 45/100
# 25/25 - 0s - loss: 0.0065 - val_loss: 0.0082 - 224ms/epoch - 9ms/step
# Epoch 46/100
# 25/25 - 0s - loss: 0.0076 - val_loss: 0.0053 - 257ms/epoch - 10ms/step
# Epoch 47/100
# 25/25 - 0s - loss: 0.0084 - val_loss: 0.0077 - 256ms/epoch - 10ms/step
# Epoch 48/100
# 25/25 - 0s - loss: 0.0067 - val_loss: 0.0044 - 240ms/epoch - 10ms/step
# Epoch 49/100
# 25/25 - 0s - loss: 0.0069 - val_loss: 0.0064 - 216ms/epoch - 9ms/step
# Epoch 50/100
# 25/25 - 0s - loss: 0.0062 - val_loss: 0.0056 - 272ms/epoch - 11ms/step
# Epoch 51/100
# 25/25 - 0s - loss: 0.0069 - val_loss: 0.0049 - 288ms/epoch - 12ms/step
# Epoch 52/100
# 25/25 - 0s - loss: 0.0057 - val_loss: 0.0058 - 224ms/epoch - 9ms/step
# Epoch 53/100
# 25/25 - 0s - loss: 0.0048 - val_loss: 0.0043 - 216ms/epoch - 9ms/step
# Epoch 54/100
# 25/25 - 0s - loss: 0.0047 - val_loss: 0.0051 - 208ms/epoch - 8ms/step
# Epoch 55/100
# 25/25 - 0s - loss: 0.0045 - val_loss: 0.0059 - 224ms/epoch - 9ms/step
# Epoch 56/100
# 25/25 - 0s - loss: 0.0055 - val_loss: 0.0050 - 208ms/epoch - 8ms/step
# Epoch 57/100
# 25/25 - 0s - loss: 0.0058 - val_loss: 0.0071 - 200ms/epoch - 8ms/step
# Epoch 58/100
# 25/25 - 0s - loss: 0.0056 - val_loss: 0.0048 - 192ms/epoch - 8ms/step
# Epoch 59/100
# 25/25 - 0s - loss: 0.0065 - val_loss: 0.0081 - 208ms/epoch - 8ms/step
# Epoch 60/100
# 25/25 - 0s - loss: 0.0056 - val_loss: 0.0057 - 228ms/epoch - 9ms/step
# Epoch 61/100
# 25/25 - 0s - loss: 0.0066 - val_loss: 0.0068 - 224ms/epoch - 9ms/step
# Epoch 62/100
# 25/25 - 0s - loss: 0.0067 - val_loss: 0.0133 - 224ms/epoch - 9ms/step
# Epoch 63/100
# 25/25 - 0s - loss: 0.0100 - val_loss: 0.0134 - 184ms/epoch - 7ms/step
# Epoch 64/100
# 25/25 - 0s - loss: 0.0102 - val_loss: 0.0140 - 208ms/epoch - 8ms/step
# Epoch 65/100
# 25/25 - 0s - loss: 0.0110 - val_loss: 0.0070 - 264ms/epoch - 11ms/step
# Epoch 66/100
# 25/25 - 0s - loss: 0.0117 - val_loss: 0.0062 - 224ms/epoch - 9ms/step
# Epoch 67/100
# 25/25 - 0s - loss: 0.0069 - val_loss: 0.0062 - 208ms/epoch - 8ms/step
# Epoch 68/100
# 25/25 - 0s - loss: 0.0077 - val_loss: 0.0101 - 216ms/epoch - 9ms/step
# Epoch 69/100
# 25/25 - 0s - loss: 0.0074 - val_loss: 0.0118 - 256ms/epoch - 10ms/step
# Epoch 70/100
# 25/25 - 0s - loss: 0.0091 - val_loss: 0.0094 - 192ms/epoch - 8ms/step
# Epoch 71/100
# 25/25 - 0s - loss: 0.0065 - val_loss: 0.0056 - 192ms/epoch - 8ms/step
# Epoch 72/100
# 25/25 - 0s - loss: 0.0058 - val_loss: 0.0073 - 200ms/epoch - 8ms/step
# Epoch 73/100
# 25/25 - 0s - loss: 0.0048 - val_loss: 0.0056 - 216ms/epoch - 9ms/step
# Epoch 74/100
# 25/25 - 0s - loss: 0.0046 - val_loss: 0.0068 - 208ms/epoch - 8ms/step
# Epoch 75/100
# 25/25 - 0s - loss: 0.0036 - val_loss: 0.0065 - 184ms/epoch - 7ms/step
# Epoch 76/100
# 25/25 - 0s - loss: 0.0042 - val_loss: 0.0065 - 192ms/epoch - 8ms/step
# Epoch 77/100
# 25/25 - 0s - loss: 0.0041 - val_loss: 0.0053 - 192ms/epoch - 8ms/step
# Epoch 78/100
# 25/25 - 0s - loss: 0.0057 - val_loss: 0.0072 - 208ms/epoch - 8ms/step
# Epoch 79/100
# 25/25 - 0s - loss: 0.0049 - val_loss: 0.0063 - 200ms/epoch - 8ms/step
# Epoch 80/100
# 25/25 - 0s - loss: 0.0051 - val_loss: 0.0073 - 208ms/epoch - 8ms/step
# Epoch 81/100
# 25/25 - 0s - loss: 0.0050 - val_loss: 0.0083 - 192ms/epoch - 8ms/step
# Epoch 82/100
# 25/25 - 0s - loss: 0.0045 - val_loss: 0.0069 - 200ms/epoch - 8ms/step
# Epoch 83/100
# 25/25 - 0s - loss: 0.0042 - val_loss: 0.0078 - 216ms/epoch - 9ms/step
# Epoch 84/100
# 25/25 - 0s - loss: 0.0039 - val_loss: 0.0059 - 208ms/epoch - 8ms/step
# Epoch 85/100
# 25/25 - 0s - loss: 0.0048 - val_loss: 0.0070 - 192ms/epoch - 8ms/step
# Epoch 86/100
# 25/25 - 0s - loss: 0.0052 - val_loss: 0.0051 - 200ms/epoch - 8ms/step
# Epoch 87/100
# 25/25 - 0s - loss: 0.0054 - val_loss: 0.0076 - 232ms/epoch - 9ms/step
# Epoch 88/100
# 25/25 - 0s - loss: 0.0044 - val_loss: 0.0077 - 232ms/epoch - 9ms/step
# Epoch 89/100
# 25/25 - 0s - loss: 0.0049 - val_loss: 0.0068 - 244ms/epoch - 10ms/step
# Epoch 90/100
# 25/25 - 0s - loss: 0.0042 - val_loss: 0.0084 - 224ms/epoch - 9ms/step
# Epoch 91/100
# 25/25 - 0s - loss: 0.0043 - val_loss: 0.0057 - 224ms/epoch - 9ms/step
# Epoch 92/100
# 25/25 - 0s - loss: 0.0038 - val_loss: 0.0071 - 232ms/epoch - 9ms/step
# Epoch 93/100
# 25/25 - 0s - loss: 0.0041 - val_loss: 0.0044 - 248ms/epoch - 10ms/step
# Epoch 94/100
# 25/25 - 0s - loss: 0.0040 - val_loss: 0.0064 - 208ms/epoch - 8ms/step
# Epoch 95/100
# 25/25 - 0s - loss: 0.0042 - val_loss: 0.0048 - 196ms/epoch - 8ms/step
# Epoch 96/100
# 25/25 - 0s - loss: 0.0036 - val_loss: 0.0070 - 232ms/epoch - 9ms/step
# Epoch 97/100
# 25/25 - 0s - loss: 0.0038 - val_loss: 0.0068 - 272ms/epoch - 11ms/step
# Epoch 98/100
# 25/25 - 0s - loss: 0.0037 - val_loss: 0.0058 - 216ms/epoch - 9ms/step
# Epoch 99/100
# 25/25 - 0s - loss: 0.0037 - val_loss: 0.0062 - 208ms/epoch - 8ms/step
# Epoch 100/100
# 25/25 - 0s - loss: 0.0033 - val_loss: 0.0058 - 192ms/epoch - 8ms/step

# %%
yhat = model.predict(X_test)
X_test_new = X_test.reshape((X_test.shape[0], X_test.shape[2]))
# invert scaling for forecast
inv_yhat = np.concatenate((yhat, X_test_new[:, 1:]), axis=1)
inv_yhat = mm.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]
# invert scaling for actual
y_test = y_test.reshape((len(y_test), 1))
inv_y = np.concatenate((y_test, X_test_new[:, 1:]), axis=1)
inv_y = mm.inverse_transform(inv_y)
inv_y = inv_y[:,0]
# calculate RMSE
rmse = mse(inv_y, inv_yhat)**0.5
print('Test RMSE: %.3f' % rmse)
# Out:
# 11/11 [==============================] - 0s 3ms/step
# Test RMSE: 0.232

# %%
df_X_ss= X_ss.reshape(X_ss.shape[0], 1, X_ss.shape[1])
y_predict = model.predict(df_X_ss)#forward pass

rescale_y_predict = mm.inverse_transform(y_predict) #reverse transformation
dataY_plot = mm.inverse_transform(y_mm)
plt.figure(figsize=(10,6)) #plotting
plt.axvline(x=770, c='r', linestyle='--') #size of the training set

plt.plot(dataY_plot, label='Actual Data') #actual plot
plt.plot(rescale_y_predict, label='Predicted Data') #predicted plot
plt.title('Spring Stage Prediction LSTM')
plt.legend()
plt.show()
# Out:
# 35/35 [==============================] - 0s 3ms/step
